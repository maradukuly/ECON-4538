# %% [markdown]
# <a href="https://colab.research.google.com/github/maradukuly/ECON-4538/blob/homework/Advanced_Labor_Economics_PS1_jl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Question 2
# Goal: Program the following optimization problem using x grid search for some value k in the space

# %%
# create uniform grid
k = range(0,10, length = 100) # where k0 is 0 and k99 (the 100th ith 10)

# create the value function as a vector of size 100
V = Vector{Float64}(undef, 100)

# create the policy function as a vector size 100
h = Vector{Float64}(undef,100)

# %% [markdown]
# To maximize the function program all functions then run the search algorithm

# %%
# create the function
function VFI(beta, A, alpha, delta)
  return(beta, A, alpha, delta)
  end
# Out:
# VFI (generic function with 1 method)
