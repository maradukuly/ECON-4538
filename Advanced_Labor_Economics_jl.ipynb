# %% [markdown]
# <a href="https://colab.research.google.com/github/maradukuly/ECON-4538/blob/main/Advanced_Labor_Economics_jl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 4
println("Hi my my name is mara and i am using julia")
typeof(a)
# Out:
# Hi my my name is mara and i am using julia
# Int64

# %% [markdown]
# # Creating functions in julia

# %%
function hypotenuse(a,b)
    return sqrt(a^2 + b^2)
end

# always have empty line at the end of function for it to run, parsing error if not
# Out:
# hypotenuse (generic function with 1 method)

# %%
# optional arguments in function
function power(x, p=2)
    return x^p
end

# %%
# running loops
n = 10
s = 0
for i in 1:n
  println(n)
end

# breaking loops
